# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/nyzy/Downloads/csv_files/plent.csv")

# %%
df1
# Out:
#             date     open      max      min    close     vol
# 0     2004-05-26   21.302   22.078   21.204   21.786  528921
# 1     2004-05-27   21.980   22.465   21.980   22.272  223724
# 2     2004-05-28   22.272   22.370   21.980   22.272   53711
# 3     2004-05-31   22.272   22.370   22.078   22.272   22738
# 4     2004-06-01   22.272   22.272   21.980   22.272   13549
# ...          ...      ...      ...      ...      ...     ...
# 3627  2019-01-17  207.000  214.000  207.000  214.000     715
# 3628  2019-01-18  214.500  218.500  197.000  215.000    5447
# 3629  2019-01-21  212.000  215.000  208.500  210.000    3591
# 3630  2019-01-22  213.000  213.000  208.000  211.000    5534
# 3631  2019-01-23  211.500  218.000  208.500  217.000    1461
#
# [3632 rows x 6 columns]

# %%
import numpy as np
import pandas as pd


def solution(files):
    # files - any of available files, i.e:
    files = ["/Users/nyzy/Downloads/csv_files/framp.csv", "/Users/nyzy/Downloads/csv_files/gnyned.csv", "/Users/nyzy/Downloads/csv_files/gwoomed.csv",
                "/Users/nyzy/Downloads/csv_files/hoilled.csv", "/Users/nyzy/Downloads/csv_files/plent.csv", "/Users/nyzy/Downloads/csv_files/throwsh.csv",
                "/Users/nyzy/Downloads/csv_files/twerche.csv", "/Users/nyzy/Downloads/csv_files/veeme.csv"]
    
    list_of_full__all_df=[]
    #df = pd.read_csv(files[0])
    for file in files:
        company_list_df=[]
        df = pd.read_csv(file)
        df["date"]=pd.to_datetime(df.date)
        df["year"]=df["date"].apply(lambda x:x.year)
        
        df["rank"] = df.groupby(["year"])["close"].rank(method="dense", ascending=False)
        df_rank_filtered=df[df["rank"]==1.0]
        print(df_rank_filtered.shape)
        company_list_df.append(df.loc[df.groupby(["year"])["vol"].idxmax()][["date","vol"]])
        company_list_df.append(df_rank_filtered[["date","close"]])
        list_of_full__all_df.append(company_list_df)

    return list_of_full__all_df

# %%
files = ["/Users/nyzy/Downloads/csv_files/framp.csv", "/Users/nyzy/Downloads/csv_files/gnyned.csv", "/Users/nyzy/Downloads/csv_files/gwoomed.csv",
            "/Users/nyzy/Downloads/csv_files/hoilled.csv", "/Users/nyzy/Downloads/csv_files/plent.csv", "/Users/nyzy/Downloads/csv_files/throwsh.csv",
                "/Users/nyzy/Downloads/csv_files/twerche.csv", "/Users/nyzy/Downloads/csv_files/veeme.csv"]


list_of_full__all_df=[]
#df = pd.read_csv(files[0])
for file in files:
    company_list_df=[]
    df = pd.read_csv(file)
    df["date"]=pd.to_datetime(df.date)
    df["year"]=df["date"].apply(lambda x:x.year)
    df["rank"] = df.groupby(["year"])["close"].rank(method="dense", ascending=False)
    df_rank_filtered=df[df["rank"]==1.0]
    company_list_df.append(df.loc[df.groupby(["year"])["vol"].idxmax()][["date","vol"]])
    company_list_df.append(df_rank_filtered[["date","close"]])
    list_of_full__all_df.append(company_list_df)

# %%
len(company_list_df)
# Out:
# 2

# %%
list_of_full__all_df
# Out:
# [[           date        vol
#   0    2005-09-23  306208914
#   171  2006-05-31   28831088
#   341  2007-02-01   18388511
#   659  2008-05-14   24150048
#   843  2009-02-06   35246018
#   1170 2010-05-26   54335576
#   1490 2011-08-31   35866126
#   1788 2012-11-06   59381774
#   2018 2013-10-10   38320297
#   2139 2014-04-09   21251451
#   2550 2015-11-30   17545094
#   2692 2016-06-28   17390752
#   2854 2017-02-16   17621885
#   3253 2018-09-21   28281682
#   3324 2019-01-09    9451453,
#              date   close
#   4    2005-09-29  2.8489
#   157  2006-05-11  2.8489
#   523  2007-10-23  4.5976
#   572  2008-01-08  4.1227
#   963  2009-07-30  3.6434
#   1289 2010-11-12  3.2556
#   1452 2011-07-07  3.8671
#   1453 2011-07-08  3.8671
#   1823 2012-12-28  4.4573
#   1973 2013-08-07  5.7230
#   2253 2014-09-23  4.7138
#   2514 2015-10-08  6.4497
#   2724 2016-08-11  5.4336
#   2985 2017-08-28  6.8750
#   2987 2017-08-30  6.8750
#   3306 2018-12-07  7.0000
# ...

# %%
file  = "/Users/nyzy/Downloads/csv_files/plent.csv"
company_list_df=[]
df = pd.read_csv(file)
df["date"]=pd.to_datetime(df.date)
df["year"]=df["date"].apply(lambda x:x.year)
company_list_df.append(df.loc[df.groupby(["year"])["vol"].idxmax()][["date","vol"]])
df["rank"] = df.groupby(["year"])["close"].rank(method="dense", ascending=False)
df_rank_filtered=df[df["rank"]==1.0]
company_list_df.append(df_rank_filtered[["date","close"]])
list_of_full__all_df.append(company_list_df)

# %%
company_list_df[1].shape
# Out:
# (18, 2)

# %%
company_list_df[1]
# Out:
#            date    close
# 115  2004-11-05   38.149
# 179  2005-02-04   40.177
# 631  2006-12-18   43.350
# 771  2007-07-16  147.160
# 931  2008-03-07  123.250
# 1383 2009-12-28   82.781
# 1389 2010-01-06   82.094
# 1738 2011-06-02   91.435
# 1743 2011-06-09   91.435
# 1744 2011-06-10   91.435
# 1952 2012-04-17  106.080
# 2350 2013-12-02  208.820
# 2616 2014-12-30  222.250
# 2701 2015-05-06  257.400
# 3019 2016-08-09  299.700
# 3221 2017-05-31  328.530
# 3373 2018-01-09  312.380
# 3631 2019-01-23  217.000

# %%
df_rank_filtered[["date","close"]]
# Out:
#            date    close
# 115  2004-11-05   38.149
# 179  2005-02-04   40.177
# 631  2006-12-18   43.350
# 771  2007-07-16  147.160
# 931  2008-03-07  123.250
# 1383 2009-12-28   82.781
# 1389 2010-01-06   82.094
# 1738 2011-06-02   91.435
# 1743 2011-06-09   91.435
# 1744 2011-06-10   91.435
# 1952 2012-04-17  106.080
# 2350 2013-12-02  208.820
# 2616 2014-12-30  222.250
# 2701 2015-05-06  257.400
# 3019 2016-08-09  299.700
# 3221 2017-05-31  328.530
# 3373 2018-01-09  312.380
# 3631 2019-01-23  217.000

# %%
import numpy as np 
from sklearn.linear_model import LinearRegression
df = pd.read_csv("/Users/nyzy/Downloads/data 2/realest.csv")

# %%
class AnalysisDataAndFitLinearRegression:

    def __init__(self):
        self.version = 1

    def analyse_and_fit_lrm(self, path):
        # a path to a dataset is "./data/realest.csv"
        # dataset can be loaded by uncommenting the line bellow

        df = pd.read_csv(path,index_col = False)
        summary_dict=dict()
        stats_df_filtered = df[(df["Bedroom"]==4.0) & (df["Bathroom"]==2.0)]
        statistics_list = [stats_df_filtered["Tax"].describe()["mean"],stats_df_filtered["Tax"].describe()["std"],stats_df_filtered["Tax"].median(),stats_df_filtered["Tax"].describe()["min"],stats_df_filtered["Tax"].describe()["max"]]
        data_frame =df[df["Space"]>800].sort_values(by="Price",ascending=False)
        summary_dict["statistics"]=statistics_list
        summary_dict["date_frame"]=data_frame
        summary_dict["number_of_observations"]=df[df["Lot"]>=df["Lot"].quantile(.8)].shape[0]

        df_filtered = self.__listwise_deletion(df)
        X=df_filtered[[ 'Bedroom', 'Space', 'Room', 'Lot', 'Tax', 'Bathroom', 'Garage',
            'Condition']]
        y = df_filtered["Price"]
        regr = LinearRegression()
        regr.fit(X, y)
        test_dict = {'Bedroom':3.0, 'Space':1500.0, 'Room':8.0, 'Lot':40.0, 'Tax':1000.0, 'Bathroom':2.0, 'Garage':1.0,
            'Condition':0.0}
        test_df = pd.DataFrame([test_dict])
        y_pred = regr.predict(test_df)
        df_coeff = pd.DataFrame(zip(X.columns, regr.coef_))
        Intercept = regr.intercept_
        intercept_dict = {"Intercept":Intercept}
        coeff_dict= dict(zip(df_coeff[0], df_coeff[1]))
        intercept_dict.update(coeff_dict)
        regression_dict = {"model_parameters":coeff_dict,"price_prediction":y_pred[0]}
        return summary_dict,regression_dict

    def __listwise_deletion(self, data: pd.DataFrame):
        return data.dropna()

# %%
s,r=AnalysisDataAndFitLinearRegression().analyse_and_fit_lrm("/Users/nyzy/Downloads/data 2/realest.csv")

# %%
regression_dict
# Out:
# {'model_parameters': {'Bedroom': -3.160238735960704,
#   'Space': 0.009663227796334398,
#   'Room': 1.6889511073197658,
#   'Lot': 0.23621323117136783,
#   'Tax': 0.004412718519150623,
#   'Bathroom': 6.3757859922123385,
#   'Garage': 4.144757426848791,
#   'Condition': 1.8357953743202866},
#  'price_prediction': 69.27677925052453}

# %%
# Out:
# {'model_parameters': {'Bedroom': -3.160238735960704,
#   'Space': 0.009663227796334398,
#   'Room': 1.6889511073197658,
#   'Lot': 0.23621323117136783,
#   'Tax': 0.004412718519150623,
#   'Bathroom': 6.3757859922123385,
#   'Garage': 4.144757426848791,
#   'Condition': 1.8357953743202866},
#  'price_prediction': 69.27677925052453}
